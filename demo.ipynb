# %% [markdown]
# # IMPORTS
# Below are the imports we use for this notebook. All of the relevant code for training, testing, and generation is in the train.py, generate.py, and test.py files. This notebook just calls these files.

# %%
import os

# %% [markdown]
# # VAE 1 GENERATIONS
#
# Below is how you run the generation code for VAE 1. 9 samples are generated, although this can be changed by changing the --samples argument to another square number like 16.

# %%
# GENERATE 9 IMAGES WITH VAE 1
os.system(
    'python3 generate.py --vae networks/experiment_1/best_val_loss_network.pkl --samples 9'
)

# %% [markdown]
# # VAE 2 GENERATIONS
#
# Below is how you run the generation code for VAE 2. 9 samples are generated.

# %%
# GENERATE 9 IMAGES WITH VAE 2
os.system(
    'python3 generate.py --vae networks/experiment_2/best_val_loss_network.pkl --samples 9'
)

# %% [markdown]
# # VAE 3 GENERATIONS
#
# Below is how you run the generation code for VAE 3. 9 samples are generated.

# %%
# GENERATE 9 IMAGES WITH VAE 3
os.system(
    'python3 generate.py --vae networks/experiment_3/best_val_loss_network.pkl --samples 9'
)
